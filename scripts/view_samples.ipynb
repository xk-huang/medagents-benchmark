# %%
import os
os.chdir("../")
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: /data1/xhuan192/codes/medagents-benchmark

# %%
from pathlib import Path
import json
import pprint
from collections import OrderedDict

# %%
data_dir = "data"
data_dir = Path(data_dir)
# print first level of the data directory
print("Data directory contents:")
dataset_name_list = [i.stem for i in data_dir.glob("*/")]
print(dataset_name_list)
# Out:
# Data directory contents:
# ['medbullets', 'pubmedqa', 'medxpertqa-r', 'mmlu', 'medmcqa', 'medqa', 'medexqa', 'medxpertqa-u', 'mmlu-pro', 'afrimedqa', 'medqa_5options', 'cache']

# %%
file_name_list = []
for file_type in ["train", "test"]:
    for suffix in ["", "_good", "_hard", "_good_reimp", "_hard_reimp"]:
        file_name_list.append(f"{file_type}{suffix}.jsonl")
print(f"File names: {file_name_list}")
# Out:
# File names: ['train.jsonl', 'train_good.jsonl', 'train_hard.jsonl', 'train_good_reimp.jsonl', 'train_hard_reimp.jsonl', 'test.jsonl', 'test_good.jsonl', 'test_hard.jsonl', 'test_good_reimp.jsonl', 'test_hard_reimp.jsonl']

# %%
for dataset_name in dataset_name_list:
    dataset_stats = OrderedDict()

    print(f"\n\nDataset: {dataset_name}")
    for file_name in file_name_list:
        # check if the file exists
        file_path = data_dir / dataset_name / file_name
        if not file_path.exists():
            # print(f"File {file_path} does not exist.")
            continue

        # print(f"File {file_path} exists.")
        for line in file_path.open("r"):
            line = line.strip()
            if not line:
                continue
            # check if the line is a valid JSON
            try:
                sample = json.loads(line)
            except json.JSONDecodeError:
                print(f"Invalid JSON in file {file_path}: {line}")
                continue
            break

        dataset_stats[file_name] =  sample.keys()
    pprint.pprint(dataset_stats)
# Out:
# Dataset: medbullets
# OrderedDict([('train.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'meta_info', 'answer_idx', 'metamap_phrases'])),
#              ('train_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'meta_info', 'answer_idx', 'metamap_phrases', 'cleanse_cot'])),
#              ('train_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'meta_info', 'answer_idx', 'metamap_phrases', 'cleanse_cot', 'predicted_answer_base_direct'])),
#              ('test.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'answer_idx', 'reason'])),
#              ('test_good.jsonl',
#               dict_keys(['question', 'answer', 'options', 'answer_idx', 'reason', 'realidx', 'cleanse_cot'])),
#              ('test_hard.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'answer_idx', 'reason'])),
#              ('test_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'answer_idx', 'reason', 'cleanse_cot'])),
#              ('test_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'answer_idx', 'reason', 'cleanse_cot', 'predicted_answer_base_direct']))])
#
#
# Dataset: pubmedqa
# OrderedDict([('train.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'answer_rationale', 'options', 'answer_idx'])),
#              ('train_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'answer_rationale', 'options', 'answer_idx', 'cleanse_cot'])),
#              ('train_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'answer_rationale', 'options', 'answer_idx', 'cleanse_cot', 'predicted_answer_base_direct'])),
#              ('test.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'answer_rationale', 'options', 'answer_idx'])),
#              ('test_good.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'answer_rationale', 'options', 'answer_idx', 'cleanse_cot'])),
#              ('test_hard.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'answer_rationale', 'options', 'answer_idx'])),
#              ('test_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'answer_rationale', 'options', 'answer_idx', 'cleanse_cot'])),
#              ('test_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'answer_rationale', 'options', 'answer_idx', 'cleanse_cot', 'predicted_answer_base_direct']))])
#
#
# Dataset: medxpertqa-r
# OrderedDict([('train.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer'])),
#              ('train_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot'])),
#              ('train_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot', 'predicted_answer_base_direct'])),
#              ('test.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer'])),
#              ('test_hard.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer'])),
#              ('test_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot'])),
#              ('test_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot', 'predicted_answer_base_direct']))])
#
#
# Dataset: mmlu
# OrderedDict([('train.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'category', 'src', 'answer'])),
#              ('train_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'category', 'src', 'answer', 'cleanse_cot'])),
#              ('train_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'category', 'src', 'answer', 'cleanse_cot', 'predicted_answer_base_direct'])),
#              ('test.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'subject', 'answer'])),
#              ('test_good.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'subject', 'answer', 'cleanse_cot'])),
#              ('test_hard.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'subject', 'answer'])),
#              ('test_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'subject', 'answer', 'cleanse_cot'])),
#              ('test_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'subject', 'answer', 'cleanse_cot', 'predicted_answer_base_direct']))])
#
#
# Dataset: medmcqa
# OrderedDict([('train.jsonl',
#               dict_keys(['question', 'realidx', 'options', 'answer_idx', 'answer'])),
#              ('train_good_reimp.jsonl',
#               dict_keys(['question', 'realidx', 'options', 'answer_idx', 'answer', 'cleanse_cot'])),
#              ('train_hard_reimp.jsonl',
#               dict_keys(['question', 'realidx', 'options', 'answer_idx', 'answer', 'cleanse_cot', 'predicted_answer_base_direct'])),
#              ('test.jsonl',
#               dict_keys(['question', 'realidx', 'options', 'answer_idx', 'answer'])),
#              ('test_good.jsonl',
#               dict_keys(['question', 'realidx', 'options', 'answer_idx', 'answer', 'cleanse_cot'])),
#              ('test_hard.jsonl',
#               dict_keys(['question', 'realidx', 'options', 'answer_idx', 'answer'])),
#              ('test_good_reimp.jsonl',
#               dict_keys(['question', 'realidx', 'options', 'answer_idx', 'answer', 'cleanse_cot'])),
#              ('test_hard_reimp.jsonl',
#               dict_keys(['question', 'realidx', 'options', 'answer_idx', 'answer', 'cleanse_cot', 'predicted_answer_base_direct']))])
#
#
# Dataset: medqa
# OrderedDict([('train.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'meta_info', 'answer_idx', 'metamap_phrases'])),
#              ('train_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'meta_info', 'answer_idx', 'metamap_phrases', 'cleanse_cot'])),
#              ('train_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'meta_info', 'answer_idx', 'metamap_phrases', 'cleanse_cot', 'predicted_answer_base_direct'])),
#              ('test.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'meta_info', 'answer_idx', 'metamap_phrases'])),
#              ('test_good.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'meta_info', 'answer_idx', 'metamap_phrases', 'cleanse_cot'])),
#              ('test_hard.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'meta_info', 'answer_idx', 'metamap_phrases'])),
#              ('test_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'meta_info', 'answer_idx', 'metamap_phrases', 'cleanse_cot'])),
#              ('test_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'answer', 'options', 'meta_info', 'answer_idx', 'metamap_phrases', 'cleanse_cot', 'predicted_answer_base_direct']))])
#
#
# Dataset: medexqa
# OrderedDict([('train.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer'])),
#              ('train_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot'])),
#              ('train_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot', 'predicted_answer_base_direct'])),
#              ('test.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer'])),
#              ('test_hard.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer'])),
#              ('test_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot'])),
#              ('test_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot', 'predicted_answer_base_direct']))])
#
#
# Dataset: medxpertqa-u
# OrderedDict([('train.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer'])),
#              ('train_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot'])),
#              ('train_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot', 'predicted_answer_base_direct'])),
#              ('test.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer'])),
#              ('test_hard.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer'])),
#              ('test_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot'])),
#              ('test_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'answer', 'cleanse_cot', 'predicted_answer_base_direct']))])
#
#
# Dataset: mmlu-pro
# OrderedDict([('train.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'category', 'src', 'answer'])),
#              ('train_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'category', 'src', 'answer', 'cleanse_cot'])),
#              ('train_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'category', 'src', 'answer', 'cleanse_cot', 'predicted_answer_base_direct'])),
#              ('test.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'category', 'src', 'answer'])),
#              ('test_good.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'category', 'src', 'answer', 'cleanse_cot'])),
#              ('test_hard.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'category', 'src', 'answer'])),
#              ('test_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'category', 'src', 'answer', 'cleanse_cot'])),
#              ('test_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'category', 'src', 'answer', 'cleanse_cot', 'predicted_answer_base_direct']))])
#
#
# Dataset: afrimedqa
# OrderedDict([('train.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'reason', 'answer'])),
#              ('train_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'reason', 'answer', 'cleanse_cot'])),
#              ('train_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'reason', 'answer', 'cleanse_cot', 'predicted_answer_base_direct'])),
#              ('test.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'reason', 'answer'])),
#              ('test_good.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'reason', 'answer', 'cleanse_cot'])),
#              ('test_hard.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'reason', 'answer'])),
#              ('test_good_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'reason', 'answer', 'cleanse_cot'])),
#              ('test_hard_reimp.jsonl',
#               dict_keys(['realidx', 'question', 'options', 'answer_idx', 'reason', 'answer', 'cleanse_cot', 'predicted_answer_base_direct']))])
#
#
# Dataset: medqa_5options
# OrderedDict([('test.jsonl',
#               dict_keys(['question', 'answer', 'options', 'meta_info', 'answer_idx'])),
#              ('test_good.jsonl',
#               dict_keys(['question', 'answer', 'options', 'meta_info', 'answer_idx', 'cleanse_cot'])),
#              ('test_hard.jsonl',
#               dict_keys(['question', 'answer', 'options', 'meta_info', 'answer_idx', 'cleanse_cot', 'predicted_answer_base_direct'])),
#              ('test_good_reimp.jsonl',
#               dict_keys(['question', 'answer', 'options', 'meta_info', 'answer_idx', 'cleanse_cot'])),
#              ('test_hard_reimp.jsonl',
#               dict_keys(['question', 'answer', 'options', 'meta_info', 'answer_idx', 'cleanse_cot', 'predicted_answer_base_direct']))])
#
#
# Dataset: cache
# OrderedDict()
