# %%
import json
from prettytable import PrettyTable
import json
import os
import random
import pandas as pd

# Read the jsonl file and convert it to a JSON list
def jsonl_to_json_list(jsonl_file_path):
    json_list = []
    with open(jsonl_file_path, 'r', encoding='utf-8') as file:
        for line in file:
            json_obj = json.loads(line.strip())  # Parse each line as JSON
            json_list.append(json_obj)
    
    return json_list

# Save the JSON list to a file
def save_as_json(json_list, output_file_path):
    with open(output_file_path, 'w', encoding='utf-8') as outfile:
        json.dump(json_list, outfile, indent=4)

def save_as_jsonl(json_list, output_file_path):
    with open(output_file_path, 'w', encoding='utf-8') as outfile:
        for json_obj in json_list:
            json.dump(json_obj, outfile)
            outfile.write('\n')

# %%
def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

def deduplicate_data(data):
    seen = set()
    deduplicated_data = []
    for item in data:
        idx = item['realidx']
        if idx not in seen:
            deduplicated_data.append(item)
            seen.add(idx)
    return deduplicated_data

def calculate_accuracy(data):
    correct_predictions = 0
    total_predictions = len(data)
    for item in data:
        if item['predicted_answer'] == item['answer_idx']:
            correct_predictions += 1
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    return accuracy

def calculate_cost_from_token_usage(data, model):
    total_cost = 0
    for item in data:
        if model == 'gpt-4o-mini':
            total_cost += item['token_usage']['prompt_tokens'] * 0.15 / 1000000 + item['token_usage']['completion_tokens'] * 0.6 / 1000000
        elif model == 'gpt-4o':
            total_cost += item['token_usage']['prompt_tokens'] * 2.5 / 1000000 + item['token_usage']['completion_tokens'] * 10 / 1000000
    return total_cost / len(data)

def calculate_time_from_data(data):
    total_time = 0
    for item in data:
        total_time += item['time_elapsed']
    return total_time / len(data)

tasks = {
    'medqa': ['test_hard'],
    'pubmedqa': ['test_hard'],
    'medmcqa': ['test_hard'],
    'medbullets': ['test_hard'],
    'mmlu': ['test_hard'],
    'mmlu-pro': ['test_hard'],
    'afrimedqa': ['test_hard'],
    'medexqa': ['test_hard'],
    'medxpertqa-u': ['test_hard'],
    'medxpertqa-r': ['test_hard'],
}
models = ['gpt-4o-mini', 'gpt-4o', 'deepseek-V3']
difficulties = ['adaptive']

print("| Model | Task | Subtask | Method | Accuracy | Cost per sample(USD) | Time per sample(s) | Total Number |")
print("|-------|------|---------|---------|----------|---------------------|-------------------|--------------|")
table = PrettyTable()
table.field_names = ["Model", "Task", "Subtask", "Difficulty", "Accuracy", "Cost per sample(USD)", "Time per sample(s)", "Total Number"]

total_cost = 0

for task in tasks:
    for model in models:
        for subtask in tasks[task]:
            for difficulty in difficulties:
                try:
                    file_path = f'./output/{task}/{model}_{task}_{subtask}_{difficulty}.json'
                    data = load_json(file_path)
                    output_path = f'../../output/{task}/{model if model != "deepseek-V3" else "DeepSeek-V3"}-{task}-{subtask}-mdagents.json'
                    save_as_json(data, output_path)
                    deduplicated_data = deduplicate_data(data)
                    accuracy = calculate_accuracy(deduplicated_data)
                    total = len(deduplicated_data)
                    cost_per_sample = calculate_cost_from_token_usage(deduplicated_data, model)
                    total_cost += cost_per_sample * total
                    print(f"| {model} | {task} | {subtask} | MDAgents | {accuracy * 100:.1f}% | {cost_per_sample} | {calculate_time_from_data(deduplicated_data)} | {total} |")
                    table.add_row([
                        model, task, subtask, difficulty,
                        f"{accuracy * 100:.1f}%",
                        cost_per_sample,
                        calculate_time_from_data(deduplicated_data),
                        total
                    ])
                except Exception as e:
                    print(f"Error loading file {file_path}: {e}")

print(table)
print(f"\nTotal cost of experiment: ${total_cost:.2f}")
# Out:
# | Model | Task | Subtask | Method | Accuracy | Cost per sample(USD) | Time per sample(s) | Total Number |
# |-------|------|---------|---------|----------|---------------------|-------------------|--------------|
# | gpt-4o-mini | medqa | test_hard | MDAgents | 22.0% | 0.012128373000000001 | 79.52511752843857 | 100 |
# | gpt-4o | medqa | test_hard | MDAgents | 36.0% | 0.11012845 | 60.32874982357025 | 100 |
# | deepseek-V3 | medqa | test_hard | MDAgents | 44.0% | 0.0 | 162.24405320167543 | 100 |
# | gpt-4o-mini | pubmedqa | test_hard | MDAgents | 23.0% | 0.010930074000000001 | 107.77486172676086 | 100 |
# | gpt-4o | pubmedqa | test_hard | MDAgents | 11.0% | 0.06935595 | 108.19114663362502 | 100 |
# | deepseek-V3 | pubmedqa | test_hard | MDAgents | 15.0% | 0.0 | 141.52637087345124 | 100 |
# | gpt-4o-mini | medmcqa | test_hard | MDAgents | 16.0% | 0.0117990975 | 44.20571577072143 | 100 |
# | gpt-4o | medmcqa | test_hard | MDAgents | 22.0% | 0.025111974999999998 | 18.03709844827652 | 100 |
# | deepseek-V3 | medmcqa | test_hard | MDAgents | 27.0% | 0.0 | 110.70617571353912 | 100 |
# | gpt-4o-mini | medbullets | test_hard | MDAgents | 14.6% | 0.007608134831460676 | 90.59730827138665 | 89 |
# | gpt-4o | medbullets | test_hard | MDAgents | 21.3% | 0.07756499999999997 | 73.45634148629864 | 89 |
# | deepseek-V3 | medbullets | test_hard | MDAgents | 23.6% | 0.0 | 140.56272806746236 | 89 |
# | gpt-4o-mini | mmlu | test_hard | MDAgents | 17.8% | 0.006234776712328766 | 34.588685430892525 | 73 |
# | gpt-4o | mmlu | test_hard | MDAgents | 24.7% | 0.02753410958904109 | 16.505744342934594 | 73 |
# | deepseek-V3 | mmlu | test_hard | MDAgents | 23.3% | 0.0 | 131.38186054686977 | 73 |
# | gpt-4o-mini | mmlu-pro | test_hard | MDAgents | 9.0% | 0.0072660404999999985 | 40.704856295585635 | 100 |
# | gpt-4o | mmlu-pro | test_hard | MDAgents | 8.0% | 0.021963224999999986 | 15.41265287399292 | 100 |
# | deepseek-V3 | mmlu-pro | test_hard | MDAgents | 11.0% | 0.0 | 126.85658850193023 | 100 |
# | gpt-4o-mini | afrimedqa | test_hard | MDAgents | 18.8% | 0.009062971875 | 47.47579701989889 | 32 |
# | gpt-4o | afrimedqa | test_hard | MDAgents | 31.2% | 0.024393984375 | 38.654342852532864 | 32 |
# | deepseek-V3 | afrimedqa | test_hard | MDAgents | 31.2% | 0.0 | 109.608025662601 | 32 |
# | gpt-4o-mini | medexqa | test_hard | MDAgents | 10.0% | 0.011012312999999998 | 42.02868599176407 | 100 |
# | gpt-4o | medexqa | test_hard | MDAgents | 13.0% | 0.026446024999999998 | 18.432367911338805 | 100 |
# | deepseek-V3 | medexqa | test_hard | MDAgents | 24.0% | 0.0 | 116.90774897813797 | 100 |
# | gpt-4o-mini | medxpertqa-u | test_hard | MDAgents | 9.0% | 0.006398313 | 67.1052932190895 | 100 |
# | gpt-4o | medxpertqa-u | test_hard | MDAgents | 5.0% | 0.04618417500000001 | 44.24793269872666 | 100 |
# | deepseek-V3 | medxpertqa-u | test_hard | MDAgents | 16.3% | 0.0 | 159.8723554148966 | 98 |
# | gpt-4o-mini | medxpertqa-r | test_hard | MDAgents | 8.0% | 0.0099271725 | 77.36877849578858 | 100 |
# | gpt-4o | medxpertqa-r | test_hard | MDAgents | 4.0% | 0.061647348484848506 | 55.24695862664117 | 99 |
# | deepseek-V3 | medxpertqa-r | test_hard | MDAgents | 14.1% | 0.0 | 165.36810532964842 | 99 |
# +-------------+--------------+-----------+------------+----------+-----------------------+--------------------+--------------+
# |    Model    |     Task     |  Subtask  | Difficulty | Accuracy |  Cost per sample(USD) | Time per sample(s) | Total Number |
# +-------------+--------------+-----------+------------+----------+-----------------------+--------------------+--------------+
# | gpt-4o-mini |    medqa     | test_hard |  adaptive  |  22.0%   |  0.012128373000000001 | 79.52511752843857  |     100      |
# |    gpt-4o   |    medqa     | test_hard |  adaptive  |  36.0%   |       0.11012845      | 60.32874982357025  |     100      |
# | deepseek-V3 |    medqa     | test_hard |  adaptive  |  44.0%   |          0.0          | 162.24405320167543 |     100      |
# | gpt-4o-mini |   pubmedqa   | test_hard |  adaptive  |  23.0%   |  0.010930074000000001 | 107.77486172676086 |     100      |
# |    gpt-4o   |   pubmedqa   | test_hard |  adaptive  |  11.0%   |       0.06935595      | 108.19114663362502 |     100      |
# | deepseek-V3 |   pubmedqa   | test_hard |  adaptive  |  15.0%   |          0.0          | 141.52637087345124 |     100      |
# | gpt-4o-mini |   medmcqa    | test_hard |  adaptive  |  16.0%   |      0.0117990975     | 44.20571577072143  |     100      |
# |    gpt-4o   |   medmcqa    | test_hard |  adaptive  |  22.0%   |  0.025111974999999998 | 18.03709844827652  |     100      |
# | deepseek-V3 |   medmcqa    | test_hard |  adaptive  |  27.0%   |          0.0          | 110.70617571353912 |     100      |
# | gpt-4o-mini |  medbullets  | test_hard |  adaptive  |  14.6%   |  0.007608134831460676 | 90.59730827138665  |      89      |
# |    gpt-4o   |  medbullets  | test_hard |  adaptive  |  21.3%   |  0.07756499999999997  | 73.45634148629864  |      89      |
# | deepseek-V3 |  medbullets  | test_hard |  adaptive  |  23.6%   |          0.0          | 140.56272806746236 |      89      |
# | gpt-4o-mini |     mmlu     | test_hard |  adaptive  |  17.8%   |  0.006234776712328766 | 34.588685430892525 |      73      |
# |    gpt-4o   |     mmlu     | test_hard |  adaptive  |  24.7%   |  0.02753410958904109  | 16.505744342934594 |      73      |
# | deepseek-V3 |     mmlu     | test_hard |  adaptive  |  23.3%   |          0.0          | 131.38186054686977 |      73      |
# | gpt-4o-mini |   mmlu-pro   | test_hard |  adaptive  |   9.0%   | 0.0072660404999999985 | 40.704856295585635 |     100      |
# |    gpt-4o   |   mmlu-pro   | test_hard |  adaptive  |   8.0%   |  0.021963224999999986 | 15.41265287399292  |     100      |
# | deepseek-V3 |   mmlu-pro   | test_hard |  adaptive  |  11.0%   |          0.0          | 126.85658850193023 |     100      |
# | gpt-4o-mini |  afrimedqa   | test_hard |  adaptive  |  18.8%   |     0.009062971875    | 47.47579701989889  |      32      |
# |    gpt-4o   |  afrimedqa   | test_hard |  adaptive  |  31.2%   |     0.024393984375    | 38.654342852532864 |      32      |
# | deepseek-V3 |  afrimedqa   | test_hard |  adaptive  |  31.2%   |          0.0          |  109.608025662601  |      32      |
# | gpt-4o-mini |   medexqa    | test_hard |  adaptive  |  10.0%   |  0.011012312999999998 | 42.02868599176407  |     100      |
# |    gpt-4o   |   medexqa    | test_hard |  adaptive  |  13.0%   |  0.026446024999999998 | 18.432367911338805 |     100      |
# | deepseek-V3 |   medexqa    | test_hard |  adaptive  |  24.0%   |          0.0          | 116.90774897813797 |     100      |
# | gpt-4o-mini | medxpertqa-u | test_hard |  adaptive  |   9.0%   |      0.006398313      |  67.1052932190895  |     100      |
# |    gpt-4o   | medxpertqa-u | test_hard |  adaptive  |   5.0%   |  0.04618417500000001  | 44.24793269872666  |     100      |
# | deepseek-V3 | medxpertqa-u | test_hard |  adaptive  |  16.3%   |          0.0          | 159.8723554148966  |      98      |
# | gpt-4o-mini | medxpertqa-r | test_hard |  adaptive  |   8.0%   |      0.0099271725     | 77.36877849578858  |     100      |
# |    gpt-4o   | medxpertqa-r | test_hard |  adaptive  |   4.0%   |  0.061647348484848506 | 55.24695862664117  |      99      |
# | deepseek-V3 | medxpertqa-r | test_hard |  adaptive  |  14.1%   |          0.0          | 165.36810532964842 |      99      |
# +-------------+--------------+-----------+------------+----------+-----------------------+--------------------+--------------+
#
# Total cost of experiment: $54.08
